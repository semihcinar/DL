# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="Rossum"></p>

# %%
# import libraries

# %%
import os
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D
from sklearn.model_selection import train_test_split
from keras import optimizers
from keras.preprocessing import image
import matplotlib.pyplot as plt
from matplotlib.image import imread

# %% [markdown]
# The Dogs vs. Cats dataset is a common computer vision dataset in which pictures are classified as either including a dog or a cat.
#
# After the dataset is well studied, it can be used to understand and practice how to design, evaluate, and apply convolutional neural networks for image classification.
#
# You will build a classifier with images and try to detect dogs versus cats using CNN.
#
# Train set includes 12500 cat-5026 dog images, validation set includes 1219 cat-1071 dog images and test set incgludes 6897 cat and dogs images together.

# %%
# read data and check how many class in train set

# %%
my_data_dir = 'C:\\Users\\sc977\\OneDrive\\ML\\DL\\breakout\\data'

# %%
os.listdir(my_data_dir)
# Out:
# ['test', 'train', 'validation']

# %%
test_path = my_data_dir+'\\test\\'
train_path = my_data_dir+'\\train\\'

# %%
val_path
# Out:
# 'C:\\Users\\sc977\\OneDrive\\ML\\DL\\breakout\\data\\test\\'

# %%
os.listdir(train_path)
# Out:
# ['cat', 'dog']

# %%
os.listdir(test_path)
# Out:
# ['10000.jpg',
#  '10001.jpg',
#  '10002.jpg',
#  '10003.jpg',
#  '10004.jpg',
#  '10005.jpg',
#  '10006.jpg',
#  '10007.jpg',
#  '10008.jpg',
#  '10009.jpg',
#  '10010.jpg',
#  '10011.jpg',
#  '10012.jpg',
#  '10013.jpg',
#  '10014.jpg',
#  '10015.jpg',
#  '10016.jpg',
#  '10017.jpg',
#  '10018.jpg',
#  '10019.jpg',
#  '10020.jpg',
#  '10021.jpg',
#  '10022.jpg',
#  '10023.jpg',
#  '10024.jpg',
#  '10025.jpg',
#  '10026.jpg',
#  '10027.jpg',
#  '10028.jpg',
#  '10029.jpg',
#  '10030.jpg',
#  '10031.jpg',
#  '10032.jpg',
#  '10033.jpg',
#  '10034.jpg',
#  '10035.jpg',
#  '10036.jpg',
#  '10037.jpg',
#  '10038.jpg',
#  '10039.jpg',
#  '10040.jpg',
#  '10041.jpg',
#  '10042.jpg',
#  '10043.jpg',
#  '10044.jpg',
#  '10045.jpg',
#  '10046.jpg',
#  '10047.jpg',
#  '10048.jpg',
#  '10049.jpg',
#  '10050.jpg',
#  '10051.jpg',
#  '10052.jpg',
#  '10053.jpg',
#  '10054.jpg',
#  '10055.jpg',
#  '10056.jpg',
#  '10057.jpg',
#  '10058.jpg',
#  '10059.jpg',
#  '10060.jpg',
#  '10061.jpg',
#  '10062.jpg',
#  '10063.jpg',
#  '10064.jpg',
#  '10065.jpg',
#  '10066.jpg',
#  '10067.jpg',
#  '10068.jpg',
#  '10069.jpg',
#  '10070.jpg',
#  '10071.jpg',
#  '10072.jpg',
#  '10073.jpg',
#  '10074.jpg',
#  '10075.jpg',
#  '10076.jpg',
#  '10077.jpg',
#  '10078.jpg',
#  '10079.jpg',
#  '10080.jpg',
#  '10081.jpg',
#  '10082.jpg',
#  '10083.jpg',
#  '10084.jpg',
#  '10085.jpg',
#  '10086.jpg',
#  '10087.jpg',
#  '10088.jpg',
#  '10089.jpg',
#  '10090.jpg',
#  '10091.jpg',
#  '10092.jpg',
#  '10093.jpg',
#  '10094.jpg',
#  '10095.jpg',
#  '10096.jpg',
#  '10097.jpg',
#  '10098.jpg',
#  '10099.jpg',
#  '10100.jpg',
#  '10101.jpg',
#  '10102.jpg',
#  '10103.jpg',
#  '10104.jpg',
#  '10105.jpg',
#  '10106.jpg',
#  '10107.jpg',
#  '10108.jpg',
#  '10109.jpg',
#  '10110.jpg',
#  '10111.jpg',
#  '10112.jpg',
#  '10113.jpg',
#  '10114.jpg',
#  '10115.jpg',
#  '10968.jpg',
#  '10969.jpg',
#  '10970.jpg',
#  '10971.jpg',
#  '10972.jpg',
#  '10973.jpg',
#  '10974.jpg',
#  '10975.jpg',
#  '10976.jpg',
#  '10977.jpg',
#  '10978.jpg',
#  '10979.jpg',
#  '10980.jpg',
#  '10981.jpg',
#  '10982.jpg',
#  '10983.jpg',
#  '10984.jpg',
#  '10985.jpg',
#  '10986.jpg',
#  '10987.jpg',
#  '10988.jpg',
#  '10989.jpg',
#  '10990.jpg',
#  '10991.jpg',
#  '10992.jpg',
#  '10993.jpg',
#  '10994.jpg',
#  '10995.jpg',
#  '10996.jpg',
#  '10997.jpg',
#  '10998.jpg',
#  '10999.jpg',
#  ...]

# %%
os.listdir(train_path+'\\cat')[0]
# Out:
# 'cat.0.jpg'

# %%
os.listdir(train_path+'\\dog')[1]
# Out:
# '2464.jpg'

# %%
cat_cell = train_path+'\\cat'+'\\cat.0.jpg'

# %%
dog_cell = train_path+'\\dog'+'\\2464.jpg'

# %% [markdown]
# **Let's check how many images there are.**

# %%
len(os.listdir(train_path+'\\cat')) +len(os.listdir(train_path+'\\dog'))
# Out:
# 17526

# %%
len(os.listdir(train_path+'\\cat'))
# Out:
# 12500

# %%
#number of cat images in train set

# %%
#number of dog images in train set

# %%
len(os.listdir(train_path+'\\dog'))
# Out:
# 5026

# %%
#take cat image at index 0 from train set
#take dog image at index 1 from train set
#compare their shapes

# %%
cat_cell=os.listdir(train_path+'\\cat\\')[0]

# %%
dog_cell=os.listdir(train_path+'\\dog\\')[1]

# %%
cat_cell= (train_path+'\\cat\\cat.0.jpg')

# %%
dog_cell= (train_path+'\\dog\\2464.jpg')

# %%
imread(cat_cell)
# Out:
# array([[[203, 164,  87],
#         [203, 164,  87],
#         [204, 165,  88],
#         ...,
#         [240, 201, 122],
#         [239, 200, 121],
#         [238, 199, 120]],
#
#        [[203, 164,  87],
#         [203, 164,  87],
#         [204, 165,  88],
#         ...,
#         [241, 202, 123],
#         [240, 201, 122],
#         [238, 199, 120]],
#
#        [[203, 164,  87],
#         [203, 164,  87],
#         [204, 165,  88],
#         ...,
#         [241, 202, 123],
#         [240, 201, 122],
#         [239, 200, 121]],
#
#        ...,
#
#        [[153, 122,  55],
#         [153, 122,  55],
#         [153, 122,  55],
#         ...,
#         [  2,   2,   0],
#         [  2,   2,   0],
#         [  2,   2,   0]],
#
#        [[152, 121,  54],
#         [152, 121,  54],
#         [152, 121,  54],
#         ...,
#         [  2,   2,   0],
#         [  2,   2,   0],
#         [  2,   2,   0]],
#
#        [[151, 120,  53],
#         [151, 120,  53],
#         [151, 120,  53],
#         ...,
#         [  1,   1,   0],
#         [  1,   1,   0],
#         [  1,   1,   0]]], dtype=uint8)

# %%
imread(dog_cell)
# Out:
# array([[[ 78,  41,  22],
#         [ 78,  41,  22],
#         [ 78,  41,  22],
#         ...,
#         [121,  93,  69],
#         [122,  94,  70],
#         [122,  94,  70]],
#
#        [[ 79,  42,  23],
#         [ 80,  43,  24],
#         [ 80,  43,  24],
#         ...,
#         [122,  94,  70],
#         [122,  94,  70],
#         [123,  95,  71]],
#
#        [[ 80,  43,  24],
#         [ 81,  44,  25],
#         [ 84,  47,  28],
#         ...,
#         [122,  94,  70],
#         [123,  95,  71],
#         [124,  96,  72]],
#
#        ...,
#
#        [[124, 134, 143],
#         [128, 138, 147],
#         [133, 143, 152],
#         ...,
#         [ 26,  29,  36],
#         [ 27,  30,  37],
#         [ 28,  31,  38]],
#
#        [[124, 134, 143],
#         [128, 138, 147],
#         [133, 143, 152],
#         ...,
#         [ 22,  25,  32],
#         [ 23,  26,  33],
#         [ 24,  27,  34]],
#
#        [[124, 134, 143],
#         [128, 138, 147],
#         [133, 143, 152],
#         ...,
#         [ 21,  24,  31],
#         [ 22,  25,  32],
#         [ 24,  27,  34]]], dtype=uint8)

# %%
cat_img=imread(cat_cell)
dog_img=imread(dog_cell)

# %%
plt.imshow(cat_img)

# %%
plt.imshow(dog_img)

# %%
cat_img.shape
# Out:
# (374, 500, 3)

# %%
dog_img.shape
# Out:
# (374, 500, 3)

# %% [markdown]
# **Let's decide on the final dimension of these images.**

# %%
x= []
y = []
for image in os.listdir(train_path+'\\cat'):
    
    img = imread(train_path+'\\cat'+'\\'+image)
    d1,d2,colors = img.shape
    x.append(d1)
    y.append(d2)

# %%
x
# Out:
# [374,
#  280,
#  499,
#  499,
#  149,
#  359,
#  374,
#  471,
#  375,
#  239,
#  177,
#  320,
#  300,
#  374,
#  500,
#  499,
#  386,
#  448,
#  166,
#  374,
#  500,
#  339,
#  198,
#  280,
#  454,
#  301,
#  407,
#  423,
#  417,
#  448,
#  336,
#  431,
#  251,
#  491,
#  332,
#  134,
#  500,
#  269,
#  462,
#  374,
#  120,
#  374,
#  390,
#  391,
#  263,
#  276,
#  300,
#  500,
#  375,
#  375,
#  440,
#  480,
#  406,
#  273,
#  374,
#  336,
#  500,
#  384,
#  422,
#  333,
#  469,
#  450,
#  500,
#  400,
#  390,
#  403,
#  299,
#  500,
#  462,
#  394,
#  375,
#  427,
#  262,
#  360,
#  499,
#  313,
#  192,
#  250,
#  388,
#  500,
#  391,
#  374,
#  320,
#  302,
#  500,
#  479,
#  437,
#  215,
#  332,
#  338,
#  183,
#  216,
#  368,
#  346,
#  333,
#  375,
#  375,
#  500,
#  406,
#  332,
#  299,
#  499,
#  217,
#  400,
#  375,
#  181,
#  268,
#  374,
#  215,
#  375,
#  375,
#  411,
#  375,
#  375,
#  200,
#  374,
#  220,
#  407,
#  375,
#  299,
#  375,
#  281,
#  375,
#  86,
#  374,
#  365,
#  273,
#  448,
#  375,
#  470,
#  497,
#  500,
#  360,
#  499,
#  403,
#  423,
#  463,
#  374,
#  375,
#  375,
#  197,
#  440,
#  337,
#  346,
#  374,
#  239,
#  391,
#  239,
#  480,
#  422,
#  375,
#  338,
#  262,
#  375,
#  288,
#  499,
#  373,
#  201,
#  368,
#  335,
#  399,
#  499,
#  500,
#  374,
#  299,
#  375,
#  499,
#  500,
#  375,
#  500,
#  377,
#  221,
#  375,
#  374,
#  499,
#  420,
#  374,
#  499,
#  240,
#  500,
#  416,
#  287,
#  287,
#  348,
#  470,
#  378,
#  270,
#  266,
#  262,
#  374,
#  374,
#  334,
#  240,
#  289,
#  269,
#  374,
#  310,
#  374,
#  103,
#  374,
#  476,
#  366,
#  318,
#  375,
#  473,
#  385,
#  499,
#  374,
#  199,
#  418,
#  164,
#  223,
#  226,
#  375,
#  374,
#  373,
#  312,
#  108,
#  313,
#  464,
#  332,
#  471,
#  200,
#  499,
#  254,
#  343,
#  360,
#  377,
#  479,
#  375,
#  258,
#  239,
#  374,
#  499,
#  195,
#  391,
#  224,
#  499,
#  281,
#  375,
#  374,
#  439,
#  245,
#  374,
#  336,
#  375,
#  333,
#  300,
#  472,
#  300,
#  335,
#  324,
#  500,
#  319,
#  353,
#  374,
#  184,
#  250,
#  478,
#  315,
#  500,
#  375,
#  364,
#  375,
#  327,
#  450,
#  374,
#  500,
#  103,
#  199,
#  445,
#  374,
#  439,
#  332,
#  375,
#  359,
#  469,
#  375,
#  499,
#  225,
#  500,
#  374,
#  143,
#  485,
#  300,
#  499,
#  352,
#  500,
#  375,
#  374,
#  374,
#  500,
#  315,
#  500,
#  374,
#  500,
#  375,
#  314,
#  500,
#  499,
#  374,
#  373,
#  270,
#  396,
#  500,
#  333,
#  129,
#  325,
#  160,
#  374,
#  374,
#  75,
#  189,
#  387,
#  323,
#  382,
#  179,
#  375,
#  259,
#  499,
#  186,
#  207,
#  412,
#  500,
#  261,
#  375,
#  499,
#  499,
#  500,
#  375,
#  279,
#  376,
#  375,
#  348,
#  243,
#  239,
#  386,
#  374,
#  372,
#  126,
#  375,
#  435,
#  380,
#  500,
#  183,
#  181,
#  200,
#  271,
#  375,
#  374,
#  491,
#  374,
#  262,
#  452,
#  261,
#  499,
#  200,
#  263,
#  210,
#  331,
#  374,
#  499,
#  351,
#  354,
#  447,
#  266,
#  256,
#  249,
#  496,
#  499,
#  448,
#  374,
#  375,
#  261,
#  375,
#  374,
#  92,
#  387,
#  374,
#  500,
#  374,
#  254,
#  137,
#  213,
#  428,
#  345,
#  499,
#  213,
#  490,
#  374,
#  363,
#  448,
#  374,
#  399,
#  447,
#  321,
#  269,
#  398,
#  480,
#  424,
#  374,
#  150,
#  375,
#  374,
#  276,
#  375,
#  374,
#  399,
#  454,
#  223,
#  375,
#  500,
#  166,
#  184,
#  374,
#  375,
#  375,
#  240,
#  499,
#  500,
#  395,
#  335,
#  162,
#  362,
#  374,
#  365,
#  375,
#  495,
#  294,
#  375,
#  375,
#  385,
#  440,
#  449,
#  230,
#  374,
#  499,
#  308,
#  262,
#  49,
#  375,
#  288,
#  333,
#  375,
#  374,
#  269,
#  405,
#  399,
#  431,
#  499,
#  282,
#  359,
#  486,
#  188,
#  374,
#  270,
#  374,
#  375,
#  375,
#  465,
#  335,
#  496,
#  381,
#  374,
#  374,
#  499,
#  375,
#  425,
#  190,
#  497,
#  262,
#  330,
#  374,
#  500,
#  499,
#  499,
#  499,
#  375,
#  375,
#  403,
#  431,
#  374,
#  260,
#  500,
#  131,
#  336,
#  264,
#  160,
#  374,
#  456,
#  239,
#  265,
#  374,
#  299,
#  375,
#  375,
#  293,
#  487,
#  255,
#  426,
#  482,
#  261,
#  404,
#  445,
#  375,
#  263,
#  246,
#  500,
#  374,
#  499,
#  436,
#  304,
#  199,
#  374,
#  375,
#  334,
#  273,
#  280,
#  480,
#  453,
#  332,
#  253,
#  215,
#  498,
#  378,
#  500,
#  298,
#  150,
#  357,
#  322,
#  500,
#  299,
#  374,
#  399,
#  375,
#  282,
#  500,
#  499,
#  415,
#  500,
#  375,
#  287,
#  226,
#  375,
#  344,
#  376,
#  334,
#  374,
#  375,
#  500,
#  300,
#  499,
#  388,
#  344,
#  499,
#  395,
#  400,
#  375,
#  174,
#  259,
#  375,
#  298,
#  150,
#  335,
#  500,
#  500,
#  374,
#  500,
#  378,
#  374,
#  375,
#  245,
#  499,
#  404,
#  297,
#  500,
#  374,
#  500,
#  326,
#  499,
#  270,
#  360,
#  200,
#  376,
#  333,
#  400,
#  374,
#  374,
#  126,
#  375,
#  439,
#  318,
#  374,
#  224,
#  333,
#  224,
#  400,
#  415,
#  375,
#  500,
#  326,
#  375,
#  402,
#  310,
#  188,
#  227,
#  319,
#  328,
#  476,
#  500,
#  374,
#  369,
#  375,
#  341,
#  374,
#  353,
#  242,
#  374,
#  375,
#  375,
#  332,
#  375,
#  500,
#  299,
#  374,
#  374,
#  465,
#  409,
#  374,
#  240,
#  282,
#  374,
#  499,
#  392,
#  334,
#  374,
#  499,
#  334,
#  334,
#  374,
#  226,
#  374,
#  500,
#  398,
#  500,
#  360,
#  376,
#  341,
#  338,
#  324,
#  239,
#  374,
#  375,
#  375,
#  149,
#  364,
#  372,
#  424,
#  375,
#  261,
#  239,
#  370,
#  381,
#  375,
#  332,
#  374,
#  375,
#  454,
#  269,
#  374,
#  375,
#  299,
#  500,
#  204,
#  420,
#  374,
#  216,
#  500,
#  499,
#  308,
#  374,
#  245,
#  374,
#  374,
#  200,
#  500,
#  499,
#  379,
#  438,
#  300,
#  341,
#  457,
#  360,
#  375,
#  499,
#  125,
#  482,
#  374,
#  375,
#  375,
#  374,
#  150,
#  375,
#  300,
#  499,
#  500,
#  361,
#  392,
#  499,
#  449,
#  150,
#  375,
#  301,
#  375,
#  158,
#  293,
#  374,
#  350,
#  440,
#  259,
#  224,
#  335,
#  274,
#  374,
#  375,
#  373,
#  375,
#  360,
#  374,
#  374,
#  374,
#  469,
#  421,
#  240,
#  374,
#  375,
#  224,
#  499,
#  361,
#  296,
#  500,
#  418,
#  500,
#  499,
#  466,
#  375,
#  146,
#  375,
#  261,
#  486,
#  375,
#  239,
#  352,
#  188,
#  374,
#  375,
#  313,
#  374,
#  398,
#  377,
#  375,
#  383,
#  500,
#  410,
#  270,
#  437,
#  375,
#  374,
#  343,
#  226,
#  315,
#  466,
#  239,
#  213,
#  422,
#  286,
#  172,
#  429,
#  498,
#  236,
#  350,
#  374,
#  332,
#  374,
#  374,
#  374,
#  375,
#  500,
#  269,
#  373,
#  405,
#  338,
#  399,
#  374,
#  365,
#  282,
#  437,
#  374,
#  382,
#  374,
#  375,
#  207,
#  374,
#  442,
#  225,
#  239,
#  183,
#  499,
#  500,
#  304,
#  374,
#  290,
#  250,
#  375,
#  250,
#  319,
#  257,
#  298,
#  400,
#  326,
#  124,
#  375,
#  466,
#  307,
#  225,
#  327,
#  500,
#  331,
#  293,
#  245,
#  333,
#  388,
#  436,
#  375,
#  193,
#  404,
#  355,
#  374,
#  240,
#  375,
#  355,
#  220,
#  448,
#  258,
#  375,
#  374,
#  124,
#  224,
#  239,
#  500,
#  347,
#  490,
#  374,
#  316,
#  262,
#  499,
#  486,
#  500,
#  374,
#  355,
#  374,
#  200,
#  300,
#  374,
#  375,
#  345,
#  475,
#  373,
#  401,
#  374,
#  375,
#  374,
#  447,
#  224,
#  374,
#  262,
#  140,
#  426,
#  499,
#  499,
#  321,
#  374,
#  351,
#  375,
#  500,
#  375,
#  450,
#  199,
#  374,
#  300,
#  500,
#  332,
#  375,
#  260,
#  330,
#  499,
#  374,
#  299,
#  200,
#  358,
#  85,
#  333,
#  109,
#  375,
#  375,
#  270,
#  355,
#  416,
#  454,
#  374,
#  374,
#  499,
#  481,
#  261,
#  500,
#  282,
#  300,
#  375,
#  374,
#  375,
#  374,
#  454,
#  374,
#  375,
#  375,
#  467,
#  428,
#  360,
#  350,
#  375,
#  281,
#  224,
#  370,
#  451,
#  180,
#  374,
#  499,
#  499,
#  375,
#  499,
#  375,
#  219,
#  399,
#  374,
#  196,
#  499,
#  477,
#  375,
#  332,
#  334,
#  500,
#  374,
#  125,
#  353,
#  375,
#  147,
#  499,
#  374,
#  435,
#  458,
#  369,
#  374,
#  296,
#  377,
#  479,
#  390,
#  188,
#  270,
#  375,
#  500,
#  375,
#  375,
#  499,
#  375,
#  241,
#  500,
#  446,
#  462,
#  396,
#  375,
#  269,
#  374,
#  374,
#  250,
#  313,
#  463,
#  323,
#  499,
#  500,
#  375,
#  374,
#  333,
#  333,
#  375,
#  374,
#  75,
#  374,
#  375,
#  369,
#  333,
#  ...]

# %%
sns.scatterplot(x,y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
np.mean(x)
# Out:
# 356.46712

# %%
np.mean(y)
# Out:
# 410.52264

# %%
# decide on a shape to use it in your model as input shape. you can either use average shape size or try something different. 128*128 is preferred here
image_shape = (350,400,3)

# %%
# help(ImageDataGenerator)

# %% [markdown]
# **Image Manipulation**
#
# We can use the ImageDataGenerator to manipulate the images with rotation, resizing, and scaling so the model becomes more robust to different images that our data set doesn't have. ImageDataGenerator does the followings.
#
# * Accepts a batch of images used for training.
# * Applies a series of random transformations to each image in the batch.
# * Replaces the original batch with randomly transformed batch.
# * Training the CNN on this randomly transformed batch.
#
# The goal of applying data augmentation is to have a more generalized model.

# %%
#use ImageDataGenerator to manipulate the images

# %%
dog_img.max()
# Out:
# 255

# %%
cat_img.max()
# Out:
# 255

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=15, 
                               width_shift_range=0.10, 
                               height_shift_range=0.10, 
                               rescale=1/255, 
                               shear_range=0.1, 
                               zoom_range=0.1, 
                               horizontal_flip=True, 
                               fill_mode='nearest')

# %%
plt.imshow(cat_img)

# %%
plt.imshow(dog_img)

# %%
plt.imshow(image_gen.random_transform(cat_img))

# %%
plt.imshow(image_gen.random_transform(dog_img))

# %%
image_gen.flow_from_directory(train_path)
# Out:
# Found 17526 images belonging to 2 classes.

# %% [markdown]
# ### Generating many manipulated images from a directory
#
#
# flow_from_directory function works with images organized in sub-directories. Your directories should include only one class of images, so one folder per class of images.
#
# main_directory/
#
# ...class_a/
#
# ......a_image_1.jpg
#
# ......a_image_2.jpg
#
# ...class_b/
#
# ......b_image_1.jpg
#
# ......b_image_2.jpg
#
# [bağlantı metni](https://drive.google.com/file/d/1ntiw1WnsWq5en96zRQmWADFxoCKS4DNc/view?usp=sharing)

# %% [markdown]
# image_gen.flow_from_directory(train_path)

# %%
image_gen.flow_from_directory(val_path)
# Out:
# Found 2290 images belonging to 2 classes.

# %% [markdown]
# # Creating the Model

# %%
#create your CNN model here

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

#model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
#model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(128))
model.add(Activation('relu'))

model.add(Dropout(0.5))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %% [markdown]
# ## Early Stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=2)

# %%
batch_size = 16
train_image_gen = image_gen.flow_from_directory(train_path,
                                               target_size=image_shape[:2],
                                                color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='binary')
# Out:
# Found 17526 images belonging to 2 classes.

# %%
test_image_gen = image_gen.flow_from_directory(test_path,
                                               target_size=image_shape[:2],
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='binary',shuffle=False)
# Out:
# Found 0 images belonging to 0 classes.

# %%
train_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
#use image_gen from above and read iamges from train and test set

# %%
test_image_gen = image_gen.flow_from_directory(test_path,
                                               target_size=image_shape[:2],
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='binary',shuffle=False)
# Out:
# Found 0 images belonging to 0 classes.

# %%
val_path = my_data_dir+'\\validation\\'

# %%
val_image_gen = image_gen.flow_from_directory(val_path,
                                               target_size=image_shape[:2],
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='binary',shuffle=False)
# Out:
# Found 2290 images belonging to 2 classes.

# %%
val_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
#show class indices in train set
# Out:
# {'cat': 0, 'dog': 1}

# %% [markdown]
# ## Model Training

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
results = model.fit_generator(train_image_gen,epochs=3,
                              validation_data=val_image_gen, callbacks=[early_stop])
# Out:
# Epoch 1/3
# 1096/1096 [==============================] - 1689s 2s/step - loss: 0.6008 - accuracy: 0.7129 - val_loss: 0.6922 - val_accuracy: 0.5493
# Epoch 2/3
# 1096/1096 [==============================] - 1568s 1s/step - loss: 0.5744 - accuracy: 0.7171 - val_loss: 0.6882 - val_accuracy: 0.5799
# Epoch 3/3
# 1096/1096 [==============================] - 1569s 1s/step - loss: 0.5538 - accuracy: 0.7293 - val_loss: 0.7233 - val_accuracy: 0.5926

# %%
results = #fit your model using train and validation set
# Out:
# Epoch 1/10
# 1096/1096 [==============================] - 355s 323ms/step - loss: 0.6045 - accuracy: 0.7126 - val_loss: 0.7166 - val_accuracy: 0.5341
# Epoch 2/10
# 1096/1096 [==============================] - 275s 250ms/step - loss: 0.5650 - accuracy: 0.7208 - val_loss: 0.6426 - val_accuracy: 0.6179
# Epoch 3/10
# 1096/1096 [==============================] - 270s 246ms/step - loss: 0.5106 - accuracy: 0.7531 - val_loss: 0.7077 - val_accuracy: 0.6354
# Epoch 4/10
# 1096/1096 [==============================] - 268s 245ms/step - loss: 0.4827 - accuracy: 0.7733 - val_loss: 0.5705 - val_accuracy: 0.7022
# Epoch 5/10
# 1096/1096 [==============================] - 272s 248ms/step - loss: 0.4562 - accuracy: 0.7911 - val_loss: 0.5862 - val_accuracy: 0.6974
# Epoch 6/10
# 1096/1096 [==============================] - 265s 242ms/step - loss: 0.4299 - accuracy: 0.8053 - val_loss: 0.4747 - val_accuracy: 0.7764
# Epoch 7/10
# 1096/1096 [==============================] - 634s 579ms/step - loss: 0.4166 - accuracy: 0.8145 - val_loss: 0.5478 - val_accuracy: 0.7402
# Epoch 8/10
# 1096/1096 [==============================] - 272s 248ms/step - loss: 0.3970 - accuracy: 0.8243 - val_loss: 0.5893 - val_accuracy: 0.7437

# %% [markdown]
# # Evaluating the Model

# %%
summary = pd.DataFrame(model.history.history)
summary.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.600751  0.712884  0.692175      0.549345
# 1  0.574379  0.717106  0.688189      0.579913
# 2  0.553824  0.729259  0.723336      0.592576

# %%
plt.figure(figsize=(10,6))
plt.plot(summary.loss, label="loss")
plt.plot(summary.val_loss, label="val_loss")
plt.legend(loc="upper right")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(summary.accuracy, label="accuracy")
plt.plot(summary.val_accuracy, label="val_accuracy")
plt.legend(loc="upper left")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.show()

# %%
model.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
model.evaluate_generator(test_image_gen)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-185-31acfd80dad9> in <module>
# ----> 1 model.evaluate_generator(test_image_gen)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in evaluate_generator(self, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#    2009     self._check_call_args('evaluate_generator')
#    2010
# -> 2011     return self.evaluate(
#    2012         generator,
#    2013         steps=steps,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1464       else:
#    1465         # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1466         data_handler = data_adapter.get_data_handler(
#    1467             x=x,
#    1468             y=y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\data_adapter.py in get_data_handler(*args, **kwargs)
#    1381   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1382     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1383   return DataHandler(*args, **kwargs)
#    1384
#    1385
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1136
#    1137     adapter_cls = select_data_adapter(x, y)
# -> 1138     self._adapter = adapter_cls(
#    1139         x,
#    1140         y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, shuffle, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     915     self._keras_sequence = x
#     916     self._enqueuer = None
# --> 917     super(KerasSequenceAdapter, self).__init__(
#     918         x,
#     919         shuffle=False,  # Shuffle is handed in the _make_callable override.
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     792     # Since we have to know the dtype of the python generator when we build the
#     793     # dataset, we have to look at a batch to infer the structure.
# --> 794     peek, x = self._peek_and_restore(x)
#     795     peek = self._standardize_batch(peek)
#     796     peek = _process_tensorlike(peek)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\data_adapter.py in _peek_and_restore(x)
#     926   @staticmethod
#     927   def _peek_and_restore(x):
# --> 928     return x[0], x
#     929
#     930   def _handle_multiprocessing(self, x, workers, use_multiprocessing,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras_preprocessing\image\iterator.py in __getitem__(self, idx)
#      52     def __getitem__(self, idx):
#      53         if idx >= len(self):
# ---> 54             raise ValueError('Asked to retrieve element {idx}, '
#      55                              'but the Sequence '
#      56                              'has length {length}'.format(idx=idx,
#
# ValueError: Asked to retrieve element 0, but the Sequence has length 0

# %%
from tensorflow.keras.preprocessing import image

# %%
preds = model.predict_generator(test_image_gen)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-188-f4d82b300d09> in <module>
# ----> 1 preds = model.predict_generator(test_image_gen)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict_generator(self, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#    2036                   'will be removed in a future version. '
#    2037                   'Please use `Model.predict`, which supports generators.')
# -> 2038     return self.predict(
#    2039         generator,
#    2040         steps=steps,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1718                         '. Consider setting it to AutoShardPolicy.DATA.')
#    1719
# -> 1720       data_handler = data_adapter.get_data_handler(
#    1721           x=x,
#    1722           batch_size=batch_size,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\data_adapter.py in get_data_handler(*args, **kwargs)
#    1381   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1382     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1383   return DataHandler(*args, **kwargs)
#    1384
#    1385
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1136
#    1137     adapter_cls = select_data_adapter(x, y)
# -> 1138     self._adapter = adapter_cls(
#    1139         x,
#    1140         y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, shuffle, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     915     self._keras_sequence = x
#     916     self._enqueuer = None
# --> 917     super(KerasSequenceAdapter, self).__init__(
#     918         x,
#     919         shuffle=False,  # Shuffle is handed in the _make_callable override.
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     792     # Since we have to know the dtype of the python generator when we build the
#     793     # dataset, we have to look at a batch to infer the structure.
# --> 794     peek, x = self._peek_and_restore(x)
#     795     peek = self._standardize_batch(peek)
#     796     peek = _process_tensorlike(peek)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\data_adapter.py in _peek_and_restore(x)
#     926   @staticmethod
#     927   def _peek_and_restore(x):
# --> 928     return x[0], x
#     929
#     930   def _handle_multiprocessing(self, x, workers, use_multiprocessing,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras_preprocessing\image\iterator.py in __getitem__(self, idx)
#      52     def __getitem__(self, idx):
#      53         if idx >= len(self):
# ---> 54             raise ValueError('Asked to retrieve element {idx}, '
#      55                              'but the Sequence '
#      56                              'has length {length}'.format(idx=idx,
#
# ValueError: Asked to retrieve element 0, but the Sequence has length 0

# %%
preds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-189-c66c8509e20f> in <module>
# ----> 1 preds
#
# NameError: name 'preds' is not defined

# %%
predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-190-fd2951b82103> in <module>
# ----> 1 predictions
#
# NameError: name 'predictions' is not defined

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(test_image_gen.classes,predictions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-192-5059ffe3ba35> in <module>
# ----> 1 print(classification_report(test_image_gen.classes,predictions))
#
# NameError: name 'predictions' is not defined

# %%
losses = pd.DataFrame(......)

# %%
# Out:
# <AxesSubplot:>

# %%
# Out:
# ['loss', 'accuracy']

# %%
# Out:
# [0.5973725318908691, 0.7532750964164734]

# %%
from tensorflow.keras.preprocessing import image

# %%
pred_probabilities =

# %%
pred_probabilities
# Out:
# array([[0.044494  ],
#        [0.04975203],
#        [0.14317203],
#        ...,
#        [0.97140694],
#        [0.8137139 ],
#        [0.8951267 ]], dtype=float32)

# %%
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
predictions = pred_probabilities > 0.5

# %%
predictions
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [ True],
#        [ True]])

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.94      0.80      1219
#            1       0.89      0.52      0.66      1071
#
#     accuracy                           0.75      2290
#    macro avg       0.79      0.73      0.73      2290
# weighted avg       0.78      0.75      0.73      2290

# %%
# Out:
# array([[1149,   70],
#        [ 509,  562]], dtype=int64)

# %%
from tensorflow.keras.models import load_model
model.save('cat_dog_detector.h5')

# %% [markdown]
# # Predicting on an Image

# %%
from PIL import Image

# %%
#read 2749.jpg from test set

# %%
# resize it as 128 * 128

# %%
# turn the image into numpy array
# Out:
# (128, 128, 3)

# %%
#reshape it as below
# Out:
# (1, 128, 128, 3)

# %%
#predict the image class with your model
# Out:
# array([[0.]], dtype=float32)

# %%
train_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
test_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}
